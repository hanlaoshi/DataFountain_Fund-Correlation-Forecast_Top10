# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
#先合并train数据集和test数据集
#fund_return数据
fund_returnA =  pd.read_csv('data/test_fund_return.csv')
fund_returnB =  pd.read_csv('data/train_fund_return.csv')
fund_return = pd.merge(fund_returnB,fund_returnA,how='left')

# %%
#benchmark_return数据（暂时没用上）
benchmark_returnA =  pd.read_csv('data/test_fund_benchmark_return.csv')
benchmark_returnB =  pd.read_csv('data/train_fund_benchmark_return.csv')
benchmark_return = pd.merge(benchmark_returnB,benchmark_returnA,how='left')

# %%
#correlation数据
test_correlation = pd.read_csv('data/test_correlation.csv')
train_correlation = pd.read_csv('data/train_correlation.csv')
df_test = pd.merge(train_correlation,test_correlation,how='left')
df_test
# Out:
#               Unnamed: 0  2015-09-30  2015-10-08  2015-10-09  2015-10-12  \
# 0          Fund 1-Fund 2    0.940802    0.941465    0.944977    0.947338
# 1          Fund 1-Fund 3    0.815630    0.830942    0.842296    0.835487
# 2          Fund 1-Fund 4    0.905049    0.906305    0.911023    0.912806
# 3          Fund 1-Fund 5    0.928636    0.931980    0.935520    0.935921
# 4          Fund 1-Fund 6    0.866698    0.871721    0.879501    0.878393
# 5          Fund 1-Fund 7    0.899932    0.900124    0.913138    0.917933
# 6          Fund 1-Fund 8    0.678303    0.681206    0.701526    0.694712
# 7          Fund 1-Fund 9    0.936052    0.936742    0.940806    0.941477
# 8         Fund 1-Fund 10    0.932397    0.932612    0.935765    0.937807
# 9         Fund 1-Fund 11    0.907933    0.906399    0.912730    0.911760
# 10        Fund 1-Fund 12    0.942285    0.945984    0.947707    0.948306
# 11        Fund 1-Fund 13    0.756565    0.767699    0.781085    0.764345
# 12        Fund 1-Fund 14    0.902304    0.904561    0.909363    0.909788
# 13        Fund 1-Fund 15    0.849593    0.852490    0.861281    0.854741
# 14        Fund 1-Fund 16    0.958136    0.959887    0.961828    0.961865
# 15        Fund 1-Fund 17    0.911439    0.914905    0.923148    0.924901
# 16        Fund 1-Fund 18    0.905841    0.907464    0.909308    0.909155
# 17        Fund 1-Fund 19    0.838423    0.841616    0.834438    0.794593
# 18        Fund 1-Fund 20    0.927980    0.928682    0.933226    0.936379
# 19        Fund 1-Fund 21    0.882215    0.882585    0.885798    0.884871
# 20        Fund 1-Fund 22    0.878024    0.883478    0.891682    0.885758
# 21        Fund 1-Fund 23    0.925868    0.926144    0.930169    0.931029
# 22        Fund 1-Fund 24    0.838756    0.839980    0.850993    0.844941
# 23        Fund 1-Fund 25    0.905378    0.906892    0.911415    0.910003
# 24        Fund 1-Fund 26    0.826810    0.829678    0.841539    0.840133
# 25        Fund 1-Fund 27    0.676281    0.679833    0.707097    0.717302
# 26        Fund 1-Fund 28    0.958394    0.958089    0.960444    0.959325
# 27        Fund 1-Fund 29    0.914225    0.915310    0.919789    0.917173
# 28        Fund 1-Fund 30    0.925855    0.934893    0.934122    0.930680
# 29        Fund 1-Fund 31    0.920787    0.922788    0.927812    0.924138
# ...                  ...         ...         ...         ...         ...
# 19870  Fund 192-Fund 199    0.880574    0.882961    0.894811    0.897100
# 19871  Fund 192-Fund 200    0.970134    0.970354    0.973147    0.971643
# 19872  Fund 193-Fund 194    0.673843    0.676905    0.722656    0.708351
# 19887    0.566834    0.549567    0.545647    0.543622
# 19888    0.625969    0.602559    0.596832    0.596681
# 19889    0.650728    0.640998    0.637421    0.634101
# 19890    0.790000    0.787257    0.785538    0.781488
# 19891    0.780738    0.774750    0.771466    0.771430
# 19892    0.770210    0.760346    0.757407    0.756934
# 19893    0.745659    0.743391    0.740404    0.737691
# 19894    0.643539    0.641412    0.638185    0.631466
# 19895    0.757470    0.758479    0.753104    0.750754
# 19896    0.785441    0.785423    0.784616    0.776517
# 19897    0.874218    0.871428    0.870977    0.869982
# 19898    0.814367    0.814522    0.813039    0.814392
# 19899    0.909187    0.912722    0.912770    0.912315
#
# [19900 rows x 540 columns]

# %%
#index数据暂时没用上
index_returnA = pd.read_csv('data/test_index_return.csv',encoding='GBK')
index_returnB =  pd.read_csv('data/train_index_return.csv',encoding='GBK')
index_return = pd.merge(index_returnB,index_returnA,how='left')

# %%
ID = df_test['Unnamed: 0']
ID
# Out:
# 0            Fund 1-Fund 2
# 1            Fund 1-Fund 3
# 2            Fund 1-Fund 4
# 3            Fund 1-Fund 5
# 4            Fund 1-Fund 6
# 5            Fund 1-Fund 7
# 6            Fund 1-Fund 8
# 7            Fund 1-Fund 9
# 8           Fund 1-Fund 10
# 9           Fund 1-Fund 11
# 10          Fund 1-Fund 12
# 11          Fund 1-Fund 13
# 12          Fund 1-Fund 14
# 13          Fund 1-Fund 15
# 14          Fund 1-Fund 16
# 15          Fund 1-Fund 17
# 16          Fund 1-Fund 18
# 17          Fund 1-Fund 19
# 18          Fund 1-Fund 20
# 19          Fund 1-Fund 21
# 20          Fund 1-Fund 22
# 21          Fund 1-Fund 23
# 22          Fund 1-Fund 24
# 23          Fund 1-Fund 25
# 24          Fund 1-Fund 26
# 25          Fund 1-Fund 27
# 26          Fund 1-Fund 28
# 27          Fund 1-Fund 29
# 28          Fund 1-Fund 30
# 29          Fund 1-Fund 31
#                ...
# 19870    Fund 192-Fund 199
# 19871    Fund 192-Fund 200
# 19872    Fund 193-Fund 194
# 19873    Fund 193-Fund 195
# 19874    Fund 193-Fund 196
# 19875    Fund 193-Fund 197
# 19876    Fund 193-Fund 198
# 19877    Fund 193-Fund 199
# 19878    Fund 193-Fund 200
# 19879    Fund 194-Fund 195
# 19880    Fund 194-Fund 196
# 19881    Fund 194-Fund 197
# 19882    Fund 194-Fund 198
# 19883    Fund 194-Fund 199
# 19884    Fund 194-Fund 200
# 19885    Fund 195-Fund 196
# 19886    Fund 195-Fund 197
# 19887    Fund 195-Fund 198
# 19888    Fund 195-Fund 199
# 19889    Fund 195-Fund 200
# 19890    Fund 196-Fund 197
# 19891    Fund 196-Fund 198
# 19892    Fund 196-Fund 199
# 19893    Fund 196-Fund 200
# 19894    Fund 197-Fund 198
# 19895    Fund 197-Fund 199
# 19896    Fund 197-Fund 200
# 19897    Fund 198-Fund 199
# 19898    Fund 198-Fund 200
# 19899    Fund 199-Fund 200
# Name: Unnamed: 0, Length: 19900, dtype: object

# %%
#由于ID格式为FundA-FundB因此需要先将其拆分为'FundA','FundB'
index = pd.concat([ID.map(lambda x:x.split('-')[0]),ID.map(lambda x:x.split('-')[1])],axis=1)
print(index)
print('--------')
index.columns = ['FundA','FundB']
print(index.columns)
# Out:
#       Unnamed: 0 Unnamed: 0
# 0         Fund 1     Fund 2
# 1         Fund 1     Fund 3
# 2         Fund 1     Fund 4
# 3         Fund 1     Fund 5
# 4         Fund 1     Fund 6
# 5         Fund 1     Fund 7
# 6         Fund 1     Fund 8
# 7         Fund 1     Fund 9
# 8         Fund 1    Fund 10
# 9         Fund 1    Fund 11
# 10        Fund 1    Fund 12
# 11        Fund 1    Fund 13
# 12        Fund 1    Fund 14
# 13        Fund 1    Fund 15
# 14        Fund 1    Fund 16
# 15        Fund 1    Fund 17
# 16        Fund 1    Fund 18
# 17        Fund 1    Fund 19
# 18        Fund 1    Fund 20
# 19        Fund 1    Fund 21
# 20        Fund 1    Fund 22
# 21        Fund 1    Fund 23
# 22        Fund 1    Fund 24
# 23        Fund 1    Fund 25
# 24        Fund 1    Fund 26
# 25        Fund 1    Fund 27
# 26        Fund 1    Fund 28
# 27        Fund 1    Fund 29
# 28        Fund 1    Fund 30
# 29        Fund 1    Fund 31
# ...          ...        ...
# 19870   Fund 192   Fund 199
# 19871   Fund 192   Fund 200
# 19872   Fund 193   Fund 194
# 19873   Fund 193   Fund 195
# 19874   Fund 193   Fund 196
# 19875   Fund 193   Fund 197
# 19876   Fund 193   Fund 198
# 19877   Fund 193   Fund 199
# 19878   Fund 193   Fund 200
# 19879   Fund 194   Fund 195
# 19880   Fund 194   Fund 196
# 19881   Fund 194   Fund 197
# 19882   Fund 194   Fund 198
# 19883   Fund 194   Fund 199
# 19884   Fund 194   Fund 200
# 19885   Fund 195   Fund 196
# 19886   Fund 195   Fund 197
# 19887   Fund 195   Fund 198
# 19888   Fund 195   Fund 199
# 19889   Fund 195   Fund 200
# 19890   Fund 196   Fund 197
# 19891   Fund 196   Fund 198
# 19892   Fund 196   Fund 199
# 19893   Fund 196   Fund 200
# 19894   Fund 197   Fund 198
# 19895   Fund 197   Fund 199
# 19896   Fund 197   Fund 200
# 19897   Fund 198   Fund 199
# 19898   Fund 198   Fund 200
# 19899   Fund 199   Fund 200
#
# [19900 rows x 2 columns]
# --------
# Index(['FundA', 'FundB'], dtype='object')

# %%
#定义函数：根据输入的数据集，起止时间，把FundA，FundB的数据提取作为特征
def day_tran(data,star_time,end_time,index=index):
    #先根据index['FundA']匹配A列数据
    fund_r = pd.concat((data['Unnamed: 0'],data[data.columns[star_time:end_time]]),axis=1)
    fund_r.rename(columns={'Unnamed: 0':"FundA"},inplace=True)
    FundA  = pd.merge(index,fund_r,how = 'left') 
#     print(FundA)
    FundA = FundA[FundA.columns[2:]]
    FundA.columns=range(0,FundA.shape[1])
    #先根据index['FundB']匹配B列数据
    fund_r.rename(columns={"FundA":"FundB"},inplace=True)
    FundB = pd.merge(index,fund_r,on = 'FundB',how = 'left',suffixes=('_x', '_y'))
    FundB = FundB[FundB.columns[2:]]
    FundB.columns=range(0,FundB.shape[1])
    return FundA,FundB

# %%
#然后运用matplotlib进行特征探索
import matplotlib.pyplot as plt
from pylab import *

# %%
FundA = 0 #选择要观察的基金组合
FundB = 1 #选择要观察的基金组合
start_time=-160
end_time=-61
plt.figure(figsize=(20, 5))
names = fund_returnA.columns[start_time:end_time] #横坐标
x = range(len(names))

feature_day = fund_returnA.columns[start_time-1:end_time-1]#因为我们预测的是第二天的相关性，所以特征要比correlation的数据提前一天

y1 = fund_return[feature_day].loc[FundA]   #基金A fund_return
y2 = fund_return[feature_day].loc[FundB]   #基金B fund_return
y3 = benchmark_return[feature_day].loc[FundA] #基金A benchmark_return
y4 = benchmark_return[feature_day].loc[FundB] #基金B benchmark_return
y5 = index_return[feature_day].mean()

#尝试组合特征，观察与correlation的拟合度（经尝试abs(y-y2)拟合度好，可作为特征）

y6 = abs(y1-y2)*3 #乘以3是为了放大折现的形状以便比较correlation线

yx = df_test[df_test.columns[start_time-end_time:]].loc[FundB-1] #这里观察的需要根据基金的组合进行调整

plt.plot(x, y1, ms=1,label=u'fund_returnA曲线图')
plt.plot(x, y2+0.1, ms=5,label=u'fund_returnB曲线图')
plt.plot(x, y3+0.2, ms=5,label=u'benchmark_returnA曲线图')
plt.plot(x, y4+0.3, ms=1,label=u'benchmark_returnB曲线图')
plt.plot(x, y5+0.4, ms=1,label=u'index曲线图')
plt.plot(x, y6+0.5, ms=1,label=u'abs（ra-rb）曲线图')
plt.plot(x, yx, ms=1,label=u'correlation曲线图')
plt.legend()  # 让图例生效
plt.xticks(x, names, rotation=100)
plt.margins(0)
plt.subplots_adjust(bottom=0.15)

# %%
#通过mean\25%\50%\75%可以看出不同基金对的相关行存在一种看似比例的关系，如第2，3对基金的相关性比其他高，因此我暂时选取mean作为特征
df_test[df_test.columns[1:]].T.describe()
# Out:
#             0           1           2           3           4           5      \
# count  539.000000  539.000000  539.000000  539.000000  539.000000  539.000000
# mean     0.759854    0.708782    0.845711    0.848326    0.674080    0.680695
# std      0.178210    0.202446    0.074588    0.103907    0.189870    0.144953
# min      0.373658    0.257826    0.692532    0.507301    0.274987    0.354085
# 25%      0.572346    0.506938    0.779350    0.781431    0.522951    0.559405
# 50%      0.808275    0.805435    0.840834    0.874084    0.654136    0.674766
# 75%      0.938039    0.873877    0.910946    0.933421    0.880203    0.792091
# max      0.979743    0.974509    0.971910    0.983099    0.968028    0.938696
#
#             6           7           8           9         ...           19890  \
# count  539.000000  539.000000  539.000000  539.000000     ...      539.000000
# mean     0.695405    0.870037    0.823886    0.810454     ...        0.823474
# std      0.171985    0.071358    0.088504    0.109249     ...        0.091162
# min      0.239802    0.654177    0.486044    0.577460     ...        0.528358
# 25%      0.532194    0.819293    0.778509    0.704833     ...        0.784136
# 50%      0.755487    0.867439    0.819477    0.820183     ...        0.822189
# 75%      0.820877    0.948508    0.884607    0.921087     ...        0.881013
# max      0.936847    0.975282    0.968036    0.961464     ...        0.978860
#
#             19891       19892       19893       19894       19895       19896  \
# count  539.000000  539.000000  539.000000  539.000000  539.000000  539.000000
# mean     0.830633    0.816576    0.812474    0.804660    0.841844    0.860427
# std      0.090023    0.097284    0.107709    0.109239    0.071778    0.065534
# min      0.547564    0.484555    0.519976    0.512851    0.529166    0.721048
# 25%      0.761011    0.771599    0.758669    0.726328    0.795064    0.815842
# 50%      0.848346    0.825460    0.835189    0.816028    0.828332    0.860201
# 75%      0.894507    0.870771    0.877836    0.888052    0.890255    0.907139
# max      0.980428    0.975238    0.976814    0.970501    0.977440    0.981774
#
#             19897       19898       19899
# count  539.000000  539.000000  539.000000
# mean     0.874233    0.864358    0.888003
# std      0.066968    0.087619    0.056083
# min      0.655573    0.516665    0.682344
# 25%      0.845741    0.816234    0.849112
# 50%      0.887775    0.890393    0.889441
# 75%      0.926788    0.925813    0.930089
# max      0.962444    0.968525    0.979252
#
# [8 rows x 19900 columns]

# %%
#特征时间跨度，并确定特征为基金对correlation的平均值、相减的绝对值（即距离）、基金对的平均值
day = 300

# %%
#叠加10天的数据作为训练集（不叠加直接用一天的数据作为特征linghtgbm预测可到82.54，叠加后会出现over_fit,通过模型融合解决）
for i in tqdm(range(10)):    
    FundA,FundB = day_tran(fund_return,-day-63,-63)
    testA = df_test.mean(axis=1)
    FundAA = FundA.mean(axis=1)
    FundBB =FundB.mean(axis=1)
    x_train = pd.concat([abs(FundA-FundB),testA,FundAA,FundBB,abs(FundAA-FundBB)],axis=1)
    q = x_train.mean()
    x_train = x_train.fillna(0).replace(0,q)
    
    if i ==0 :
        xtrain = x_train
        ytrain = df_test[df_test.columns[-3]]
    else:
        xtrain = pd.concat([xtrain,x_train])
        ytrain = pd.concat([ytrain,df_test[df_test.columns[-3-i]]])
# Out:
# 100%|██████████| 10/10 [03:35<00:00, 21.53s/it]

# %%
#test数据集
FundA,FundB = day_tran(fund_return,-day,None)
testA = df_test.mean(axis=1)
FundAA = FundA.mean(axis=1)
FundBB =FundB.mean(axis=1)
x_test = pd.concat([abs(FundA-FundB),testA,FundAA,FundBB,abs(FundAA-FundBB)],axis=1)
q = x_test.mean()
x_test = x_test.fillna(0).replace(0,q)

#val1数据集
FundA,FundB = day_tran(fund_return,-day-61,-61)
testA = df_test.mean(axis=1)
FundAA = FundA.mean(axis=1)
FundBB =FundB.mean(axis=1)
xval = pd.concat([abs(FundA-FundB),testA,FundAA,FundBB,abs(FundAA-FundBB)],axis=1)
q = xval.mean()
xval1 = xval.fillna(0).replace(0,q)

#val2数据集
FundA,FundB = day_tran(fund_return,-day-62,-62)
testA = df_test.mean(axis=1)
FundAA = FundA.mean(axis=1)
FundBB =FundB.mean(axis=1)
xval = pd.concat([abs(FundA-FundB),testA,FundAA,FundBB,abs(FundAA-FundBB)],axis=1)
q = xval.mean()
xval2 = xval.fillna(0).replace(0,q)

# %%
xtrain.shape,ytrain.shape,x_test.shape,xval1.shape,xval2.shape
# Out:
# ((199000, 304), (199000,), (19900, 304), (19900, 304), (19900, 304))

# %%
#定义结果评价函数，可通过倒数第2天的correlation数据，预测倒数第1天的correlation，以验证模型效果
from sklearn.metrics import mean_absolute_error  
def modelFeval(y_pred,labels):
    sc1 = mean_absolute_error(labels,y_pred)
    diff = 0
    count = 0
    for i in range(len(y_pred)):
        diff += abs((y_pred[i]-labels[i]) / (1.5-labels[i]))
        count +=1
    sc2 = diff/count
    sc = ((2/(2+sc1+sc2))**2)
    return 'myFeval',float(sc)

# %%
#定义lightgbm模型
def lgbPRD(x_train,target,val,val2,x_test,params,num_boost_round=10000):
    import lightgbm as lgb
    xg_train = lgb.Dataset(np.array(x_train),target)

    #xg_test1 = xgb.DMatrix(np.array(test1))
    #cv调参
    #cv = xgb.cv(params, xg_train, num_boost_round=num_boost_round, nfold=4, seed=2018, stratified=False,
             #early_stopping_rounds=25,verbose_eval=100,feval=myFeval,show_stdv=True)
    #nround = cv.shape[0]
    #训练模型
    bst = lgb.train(params, xg_train,num_boost_round)
    
    
    return bst.predict( x_test ),bst.predict( val ),bst.predict( val2 )

# %%
lgb_params = {
    'seed': 0,
    'application':'regression_l1',
    'boosting':'gbdt',
#     'device':'gpu',
    'learning_rate': 0.09,
    'max_depth':1,
    'feature_fraction':0.7,
    'bagging_fraction':0.6,
    'bagging_freq':20,
    'lambda_l1':18,
}

# %%
#预测test,val1,val2值
lgypred,lgyval1,lgyval2 = lgbPRD(xtrain,ytrain,xval1,xval2,x_test,lgb_params,2000)

# %%
#根据lgyval1验证值进行调参
modelFeval(lgyval1,df_test['2017-12-14'])
# Out:
# ('myFeval', 0.8081314067424583)

# %%
#定义xgboost模型
def xgbPRD(x_train,target,val,val2,x_test,params,num_boost_round=1000):
    import xgboost as xgb
    #xgb矩阵转换
    xg_train = xgb.DMatrix(np.array(x_train),target)
    xg_test = xgb.DMatrix(np.array(x_test))
    xg_val = xgb.DMatrix(np.array(val))
    xg_val2 = xgb.DMatrix(np.array(val2))
    #xg_test1 = xgb.DMatrix(np.array(test1))
    #cv调参
    #cv = xgb.cv(params, xg_train, num_boost_round=num_boost_round, nfold=4, seed=2018, stratified=False,
             #early_stopping_rounds=25,verbose_eval=100,feval=myFeval,show_stdv=True)
    #nround = cv.shape[0]
    #训练模型
    bst = xgb.train(params, xg_train,num_boost_round)
    
    
    return bst.predict( xg_test ),bst.predict( xg_val ),bst.predict( xg_val2 )

# %%
xgb_params = {
    'seed': 0,
    'silent': 1,
    'learning_rate': 0.06,
#     'objective': 'gpu:reg:linear',
    'objective': 'reg:linear',
    'max_depth': 1,
    'eval_metric': 'rmse',
    'nthread':-1,
   # 'tree_method':"gpu_hist",
    'subsample':0.4,
    'alpha':50,
    'colsample_bytree':0.1,
    'lambda':6,
}

# %%
ypred,yval1,yval2 = xgbPRD(xtrain,ytrain,xval1,xval2,x_test,xgb_params,2100)

# %%
#调参
modelFeval(yval1,df_test['2017-12-14'])

# %%
#融合lgb和xgb预测结果作为特征，进行预测
xstack = np.vstack([yval1,lgyval1]).T
vstack = np.vstack([yval2,lgyval2]).T
tstack = np.vstack([ypred,lgypred]).T

# %%
lgbs_params = {
    'seed': 0,
    'application':'regression_l1',
    'boosting':'gbdt',
    #'device':'gpu',
    'learning_rate': 0.004,
    'max_depth':1,
    'feature_fraction':0.7,
    'bagging_fraction':0.6,
    'bagging_freq':1,
    'lambda_l1':0.1,
}

# %%
stack_pred,stack_val,stack_val1 = lgbPRD(xstack,df_test['2017-12-14'],vstack,vstack,tstack,lgbs_params,1900)

# %%
#继续用于调参,最终结果为82.64
modelFeval(stack_val,df_test['2017-12-13'])

# %%
#输出结果
df = pd.DataFrame({'ID':ID,'value':stac_pred})
df.to_csv('10.23ceshi.csv',index=None)
